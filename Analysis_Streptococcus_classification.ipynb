# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import parallel_coordinates

# warnings -> to silence warnings
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("data/Dati_Matemaldomics.csv", delimiter=';', index_col='ID Strain')
df
# Out:
#                 Year Region Animal species of origin Organ of origin     ST  \
# ID Strain
# V13        ante 2004    NaN                      Dog           Urine   ST13
# V142            2008    NaN                      Dog           Urine   ST23
# V151            2008    NaN                      Dog             Ear   ST95
# V160            2011    NaN                      Dog            Skin   ST15
# V161            2011    NaN                      Cat            Lung    ST9
# ...              ...    ...                      ...             ...    ...
# V800            2021    NaN                   Bovine            Milk  ST307
# V82             2006    NaN                      Cat       Intestine    ST9
# V90             2006    NaN                      Dog             Pus   ST13
# V91             2006    NaN                      Dog       Intestine    ST9
# V95             2006    NaN                    Swine          Spleen  ST705
#
#                               Species  \
# ID Strain
# V13               Streptococcus_canis
# V142              Streptococcus_canis
# V151              Streptococcus_canis
# V160              Streptococcus_canis
# V161              Streptococcus_canis
# ...                               ...
# V800       Streptococcus_dysgalactiae
# V82               Streptococcus_canis
# V90               Streptococcus_canis
# V91               Streptococcus_canis
# V95        Streptococcus_dysgalactiae
#
#                                       Putative Subspecies LANCEFIELD GROUP  \
# ID Strain
# V13                                   Streptococcus canis                G
# V142                                  Streptococcus canis                G
# V151                                  Streptococcus canis                G
# V160                                  Streptococcus canis                G
# V161                                  Streptococcus canis                G
# ...                                                   ...              ...
# V800       Streptococcus dysgalactiae subsp. dysgalactiae                C
# V82                                   Streptococcus canis                G
# V90                                   Streptococcus canis                G
# V91                                   Streptococcus canis                G
# V95         Streptococcus dysgalactiae subsp. equisimilis                C
#
#           Haemolysis  2021,944237  ... scpA sda ska slo smeZ spec speg spek  \
# ID Strain                          ...
# V13                b          NaN  ...    0   0   0   0    0    0    0    0
# V142               b          NaN  ...    0   0   0   0    0    0    0    0
# V151               b          NaN  ...    0   0   0   0    0    0    0    0
# V160               b          NaN  ...    0   0   0   0    0    0    0    0
# V161               b          NaN  ...    0   0   0   0    0    0    0    0
# ...              ...          ...  ...  ...  ..  ..  ..  ...  ...  ...  ...
# V800               a  5,57269E-05  ...    0   1   0   0    0    0    0    0
# V82                b          NaN  ...    0   0   0   0    0    0    0    0
# V90                b          NaN  ...    0   0   0   0    0    0    0    0
# V91                b          NaN  ...    0   0   0   0    0    0    0    0
# V95                b  4,53898E-05  ...    0   0   0   0    0    0    0    0
#
#           spel spem
# ID Strain
# V13          0    0
# V142         0    0
# V151         0    0
# V160         0    0
# V161         0    0
# ...        ...  ...
# V800         0    0
# V82          0    0
# V90          0    0
# V91          0    0
# V95          0    0
#
# [154 rows x 369 columns]

# %%
# load dataset
metadati = df[['Year','Region','Animal species of origin','Organ of origin']]
principali = df[['ST','Species','Putative Subspecies','LANCEFIELD GROUP','Haemolysis']]
maldi = df[df.columns[11:315]]
antibiotici = df[df.columns[315:324]]
geni_antibiotico = df[df.columns[324:352]]
virulenza = df[df.columns[352:370]]

print(f"Record:{df.shape[0]}")
print(f"Feature totali:{df.shape[1]}")
print(f"Feature metadati origine: {metadati.shape[1]}")
print(f"Feature informazioni principali: {principali.shape[1]}")
print(f"Feature picchi MALDI: {maldi.shape[1]}")
print(f"Feature sensibilità agli antibiotici: {antibiotici.shape[1]}")
print(f"Feature geni di antibiotico-resistenza: {geni_antibiotico.shape[1]}")
print(f"Feature fattori di virulenza: {virulenza.shape[1]}")

df.head(10)
# Out:
# Record:154
# Feature totali:369
# Feature metadati origine: 4
# Feature informazioni principali: 5
# Feature picchi MALDI: 304
# Feature sensibilità agli antibiotici: 9
# Feature geni di antibiotico-resistenza: 28
# Feature fattori di virulenza: 17
#                 Year  Region Animal species of origin Organ of origin     ST  \
# ID Strain
# V13        ante 2004     NaN                      Dog           Urine   ST13
# V142            2008     NaN                      Dog           Urine   ST23
# V151            2008     NaN                      Dog             Ear   ST95
# V160            2011     NaN                      Dog            Skin   ST15
# V161            2011     NaN                      Cat            Lung    ST9
# V175            2018     NaN                      Dog      Septicemia   ST13
# V186            2019     NaN                      Dog             Ear    ST9
# V188            2019     NaN                      Dog       Intestine  ST240
# V190            2019   Lazio                   Bovine            Milk  ST706
# V195            2016  Umbria                   Bovine            Milk    ST9
#
#                               Species  \
# ID Strain
# V13               Streptococcus_canis
# V142              Streptococcus_canis
# V151              Streptococcus_canis
# V160              Streptococcus_canis
# V161              Streptococcus_canis
# V175       Streptococcus_dysgalactiae
# V186              Streptococcus_canis
# V188       Streptococcus_dysgalactiae
# V190       Streptococcus_dysgalactiae
# V195              Streptococcus_canis
#
#                                       Putative Subspecies LANCEFIELD GROUP  \
# ID Strain
# V13                                   Streptococcus canis                G
# V142                                  Streptococcus canis                G
# V151                                  Streptococcus canis                G
# V160                                  Streptococcus canis                G
# V161                                  Streptococcus canis                G
# V175        Streptococcus dysgalactiae subsp. equisimilis                C
# V186                                  Streptococcus canis                G
# V188        Streptococcus dysgalactiae subsp. equisimilis                A
# V190       Streptococcus dysgalactiae subsp. dysgalactiae                C
# V195                                  Streptococcus canis                G
#
#           Haemolysis  2021,944237  ... scpA sda ska slo smeZ spec speg spek  \
# ID Strain                          ...
# V13                b          NaN  ...    0   0   0   0    0    0    0    0
# V142               b          NaN  ...    0   0   0   0    0    0    0    0
# V151               b          NaN  ...    0   0   0   0    0    0    0    0
# V160               b          NaN  ...    0   0   0   0    0    0    0    0
# V161               b          NaN  ...    0   0   0   0    0    0    0    0
# V175               b          NaN  ...    0   0   0   0    0    0    1    0
# V186               b          NaN  ...    0   0   0   0    0    0    0    0
# V188               b  4,40964E-05  ...    0   0   0   0    0    0    1    0
# V190               a  5,38515E-05  ...    0   0   0   0    0    0    0    0
# V195               b          NaN  ...    0   0   0   0    0    0    0    0
#
#           spel spem
# ID Strain
# V13          0    0
# V142         0    0
# V151         0    0
# V160         0    0
# V161         0    0
# V175         0    0
# V186         0    0
# V188         0    0
# V190         0    1
# V195         0    0
#
# [10 rows x 369 columns]

# %% [markdown]
# # Analysis metadati

# %% [markdown]
# **Data preparation**

# %%
#Dato che non si può convertire ante 2004 in intero lo sostituisco con 2003 anche se non considera solo il 2003 ma tutti gli anni prima
metadati = metadati.replace('ante 2004','2003')
metadati['Year']=pd.to_numeric(metadati['Year'])
metadati['target'] = principali["Putative Subspecies"]

# %%
metadati.sample(10)
# Out:
#            Year    Region Animal species of origin Organ of origin  \
# ID Strain
# V474       2020       NaN                      Dog             Ear
# V4         2003       NaN                      Dog             Ear
# V71        2005    Umbria                    Swine            Lung
# V785       2021     Lazio                   Bovine            Milk
# V292       2020  Calabria                   Bovine            Milk
# V289       2020       NaN                      Dog            Lung
# V755       2021     LUPPI                   Bovine            Milk
# V450       2021       NaN                    Horse            Skin
# V782       2021  Calabria                   Bovine            Milk
# V688       2021     Lazio                    Ovine            Skin
#
#                                                    target
# ID Strain
# V474                                  Streptococcus canis
# V4                                    Streptococcus canis
# V71         Streptococcus dysgalactiae subsp. equisimilis
# V785       Streptococcus dysgalactiae subsp. dysgalactiae
# V292       Streptococcus dysgalactiae subsp. dysgalactiae
# V289                                  Streptococcus canis
# V755       Streptococcus dysgalactiae subsp. dysgalactiae
# V450        Streptococcus dysgalactiae subsp. equisimilis
# V782       Streptococcus dysgalactiae subsp. dysgalactiae
# V688       Streptococcus dysgalactiae subsp. dysgalactiae

# %%
print("Valori nulli per feature:")
metadati.isnull().sum()
# Out:
# Valori nulli per feature:
# Year                         0
# Region                      65
# Animal species of origin     0
# Organ of origin              5
# target                       0
# dtype: int64

# %%
print("Percentuale valori nulli per feature:")
metadati.isnull().sum() / metadati.shape[0] *100
# Out:
# Percentuale valori nulli per feature:
# Year                         0.000000
# Region                      42.207792
# Animal species of origin     0.000000
# Organ of origin              3.246753
# target                       0.000000
# dtype: float64

# %% [markdown]
# Per rimuovere i valori nulli:
# - Region: la percentuale di nulli è alta quindi preferisco non utilizzare la colonna per futuri modelli
# - Organ of origin: la percentuale di nulli è bassa quindi li sostituisco con il valora più frequente, eviterò comunque di utilizzarla per previsioni

# %%
plt.figure(figsize=(12,4))
plt.title(label="Year occurences")
sns.countplot(x="Year", data=metadati, hue='target')
plt.ylabel("Occurences")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title(label="Region occurences")
sns.countplot(y="Region", data=metadati, hue='target')
plt.xlabel("Occurences")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,4))
plt.title(label="Animal occurences")
sns.countplot(y="Animal species of origin", data=metadati, hue='target')
plt.xlabel("Occurences")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,7))
plt.title(label="Organ of origin occurences")
sns.countplot(y="Organ of origin", data=metadati, hue='target')
plt.xlabel("Occurences")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Analisi Principali

# %%
principali.dtypes
# Out:
# ST                     object
# Species                object
# Putative Subspecies    object
# LANCEFIELD GROUP       object
# Haemolysis             object
# dtype: object

# %%
principali
# Out:
#               ST                     Species  \
# ID Strain
# V13         ST13         Streptococcus_canis
# V142        ST23         Streptococcus_canis
# V151        ST95         Streptococcus_canis
# V160        ST15         Streptococcus_canis
# V161         ST9         Streptococcus_canis
# ...          ...                         ...
# V800       ST307  Streptococcus_dysgalactiae
# V82          ST9         Streptococcus_canis
# V90         ST13         Streptococcus_canis
# V91          ST9         Streptococcus_canis
# V95        ST705  Streptococcus_dysgalactiae
#
#                                       Putative Subspecies LANCEFIELD GROUP  \
# ID Strain
# V13                                   Streptococcus canis                G
# V142                                  Streptococcus canis                G
# V151                                  Streptococcus canis                G
# V160                                  Streptococcus canis                G
# V161                                  Streptococcus canis                G
# ...                                                   ...              ...
# V800       Streptococcus dysgalactiae subsp. dysgalactiae                C
# V82                                   Streptococcus canis                G
# V90                                   Streptococcus canis                G
# V91                                   Streptococcus canis                G
# V95         Streptococcus dysgalactiae subsp. equisimilis                C
#
#           Haemolysis
# ID Strain
# V13                b
# V142               b
# V151               b
# V160               b
# V161               b
# ...              ...
# V800               a
# V82                b
# V90                b
# V91                b
# V95                b
#
# [154 rows x 5 columns]

# %%
principali.isnull().sum()
# Out:
# ST                     0
# Species                0
# Putative Subspecies    0
# LANCEFIELD GROUP       0
# Haemolysis             0
# dtype: int64

# %%
sns.histplot(data=principali, y="Putative Subspecies", kde=True)
# Out:
# <AxesSubplot: xlabel='Count', ylabel='Putative Subspecies'>

# %%
#sns.countplot(y="Putative Subspecies", data=principali)

# %%
sns.countplot(y="Species", data=principali, hue="Putative Subspecies")
# Out:
# <AxesSubplot: xlabel='count', ylabel='Species'>

# %%
fig = plt.figure(figsize=(10, 12))
sns.countplot(y="ST", data=principali)
plt.show()

# %%
sns.countplot(y="LANCEFIELD GROUP", data=principali, hue="Putative Subspecies")
# Out:
# <AxesSubplot: xlabel='count', ylabel='LANCEFIELD GROUP'>

# %%
principali = principali.replace('b ','b')
sns.countplot(y="Haemolysis", data=principali, hue="Putative Subspecies")
# Out:
# <AxesSubplot: xlabel='count', ylabel='Haemolysis'>

# %% [markdown]
# # Analisi Picchi Maldi

# %%
maldi
# Out:
#            2057,143278 2064,798679  2071,138797  2085,647901  2103,986922  \
# ID Strain
# V13        7,98659E-05         NaN          NaN          NaN   8,6366E-05
# V142               NaN         NaN  4,95094E-05   4,4623E-05   7,7739E-05
# V151               NaN         NaN  6,02675E-05  4,77862E-05  0,000100212
# V160               NaN         NaN  6,55556E-05          NaN  8,85014E-05
# V161               NaN         NaN          NaN          NaN  7,72199E-05
# ...                ...         ...          ...          ...          ...
# V800       5,54677E-05         NaN          NaN  6,04758E-05  0,000104711
# V82        4,27382E-05         NaN          NaN          NaN  6,63897E-05
# V90                NaN         NaN  5,06192E-05          NaN  8,87478E-05
# V91                NaN         NaN  4,77643E-05          NaN   8,5441E-05
# V95        4,83904E-05         NaN          NaN          NaN  6,96373E-05
#
#            2117,879078  2129,309534  2143,905333   2173,98153  2188,116404  \
# ID Strain
# V13                NaN  5,18954E-05  4,71446E-05  6,79758E-05  4,98065E-05
# V142               NaN  4,71991E-05          NaN  9,10179E-05          NaN
# V151               NaN          NaN  4,66259E-05  5,38334E-05  5,36443E-05
# V160               NaN  5,06035E-05          NaN  6,73724E-05          NaN
# V161               NaN          NaN          NaN          NaN          NaN
# ...                ...          ...          ...          ...          ...
# V800               NaN          NaN          NaN  0,000117229          NaN
# V82                NaN          NaN          NaN  5,30903E-05  4,95847E-05
# V90                NaN          NaN          NaN          NaN          NaN
# V91        4,61038E-05          NaN          NaN  5,44704E-05          NaN
# V95                NaN  4,81778E-05  4,21358E-05  6,38252E-05          NaN
#
#            ... 13617,65054  14104,26499  14945,23828  15048,68998 15154,39575  \
# ID Strain  ...
# V13        ...         NaN          NaN   6,6474E-05  0,000142108         NaN
# V142       ...         NaN          NaN  8,50988E-05  0,000194467         NaN
# V151       ...         NaN          NaN  9,21027E-05  6,97349E-05         NaN
# V160       ...         NaN          NaN   9,8051E-05  0,000135981         NaN
# V161       ...         NaN          NaN  8,86343E-05  0,000203245         NaN
# ...        ...         ...          ...          ...          ...         ...
# V800       ...         NaN  3,59969E-05  7,29765E-05  5,96036E-05         NaN
# V82        ...         NaN          NaN  8,98385E-05  0,000143522         NaN
# V90        ...         NaN          NaN  0,000103564  0,000137316         NaN
# V91        ...         NaN          NaN  9,31594E-05  0,000213903         NaN
# V95        ...         NaN          NaN  6,61353E-05  4,52823E-05         NaN
#
#           15353,52046  15399,07159 15495,16655 16076,29338 16202,09535
# ID Strain
# V13               NaN          NaN         NaN         NaN         NaN
# V142              NaN          NaN         NaN         NaN         NaN
# V151              NaN          NaN         NaN         NaN         NaN
# V160              NaN          NaN         NaN         NaN         NaN
# V161              NaN          NaN         NaN         NaN         NaN
# ...               ...          ...         ...         ...         ...
# V800              NaN          NaN         NaN         NaN         NaN
# V82               NaN          NaN         NaN         NaN         NaN
# V90               NaN  5,13985E-05         NaN         NaN         NaN
# V91               NaN          NaN         NaN         NaN         NaN
# V95               NaN          NaN         NaN         NaN         NaN
#
# [154 rows x 304 columns]

# %%
maldi.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# 5780,539599    140
# 6587,606933    139
# 2423,645677    138
# 2535,074449    138
# 6814,418663    138
# 5283,615576    138
# 3406,307673    138
# 5114,565557    138
# 2392,41521     138
# 4877,931808    138
# 9652,709405    138
# 2249,262227    137
# 15353,52046    137
# 5296,883734    136
# 6861,319414    136
# 2490,961213    136
# 5639,896531    136
# 3061,280788    136
# 4142,664282    136
# 15495,16655    136
# dtype: int64

# %%
#sostituisco tutti i NaN con 0
maldi.fillna(0,inplace=True)

# %% [markdown]
# ##### Preparazione dati maldi

# %%
maldi = maldi.replace(',', '.', regex=True)
maldi
# Out:
#            2057,143278 2064,798679  2071,138797  2085,647901  2103,986922  \
# ID Strain
# V13        7.98659E-05           0            0            0   8.6366E-05
# V142                 0           0  4.95094E-05   4.4623E-05   7.7739E-05
# V151                 0           0  6.02675E-05  4.77862E-05  0.000100212
# V160                 0           0  6.55556E-05            0  8.85014E-05
# V161                 0           0            0            0  7.72199E-05
# ...                ...         ...          ...          ...          ...
# V800       5.54677E-05           0            0  6.04758E-05  0.000104711
# V82        4.27382E-05           0            0            0  6.63897E-05
# V90                  0           0  5.06192E-05            0  8.87478E-05
# V91                  0           0  4.77643E-05            0   8.5441E-05
# V95        4.83904E-05           0            0            0  6.96373E-05
#
#            2117,879078  2129,309534  2143,905333   2173,98153  2188,116404  \
# ID Strain
# V13                  0  5.18954E-05  4.71446E-05  6.79758E-05  4.98065E-05
# V142                 0  4.71991E-05            0  9.10179E-05            0
# V151                 0            0  4.66259E-05  5.38334E-05  5.36443E-05
# V160                 0  5.06035E-05            0  6.73724E-05            0
# V161                 0            0            0            0            0
# ...                ...          ...          ...          ...          ...
# V800                 0            0            0  0.000117229            0
# V82                  0            0            0  5.30903E-05  4.95847E-05
# V90                  0            0            0            0            0
# V91        4.61038E-05            0            0  5.44704E-05            0
# V95                  0  4.81778E-05  4.21358E-05  6.38252E-05            0
#
#            ... 13617,65054  14104,26499  14945,23828  15048,68998 15154,39575  \
# ID Strain  ...
# V13        ...           0            0   6.6474E-05  0.000142108           0
# V142       ...           0            0  8.50988E-05  0.000194467           0
# V151       ...           0            0  9.21027E-05  6.97349E-05           0
# V160       ...           0            0   9.8051E-05  0.000135981           0
# V161       ...           0            0  8.86343E-05  0.000203245           0
# ...        ...         ...          ...          ...          ...         ...
# V800       ...           0  3.59969E-05  7.29765E-05  5.96036E-05           0
# V82        ...           0            0  8.98385E-05  0.000143522           0
# V90        ...           0            0  0.000103564  0.000137316           0
# V91        ...           0            0  9.31594E-05  0.000213903           0
# V95        ...           0            0  6.61353E-05  4.52823E-05           0
#
#           15353,52046  15399,07159 15495,16655 16076,29338 16202,09535
# ID Strain
# V13                 0            0           0           0           0
# V142                0            0           0           0           0
# V151                0            0           0           0           0
# V160                0            0           0           0           0
# V161                0            0           0           0           0
# ...               ...          ...         ...         ...         ...
# V800                0            0           0           0           0
# V82                 0            0           0           0           0
# V90                 0  5.13985E-05           0           0           0
# V91                 0            0           0           0           0
# V95                 0            0           0           0           0
#
# [154 rows x 304 columns]

# %%
columns = maldi.columns
for column in columns:
    maldi[column] = maldi[column].astype(float)
maldi
# Out:
#            2057,143278  2064,798679  2071,138797  2085,647901  2103,986922  \
# ID Strain
# V13           0.000080          0.0     0.000000     0.000000     0.000086
# V142          0.000000          0.0     0.000050     0.000045     0.000078
# V151          0.000000          0.0     0.000060     0.000048     0.000100
# V160          0.000000          0.0     0.000066     0.000000     0.000089
# V161          0.000000          0.0     0.000000     0.000000     0.000077
# ...                ...          ...          ...          ...          ...
# V800          0.000055          0.0     0.000000     0.000060     0.000105
# V82           0.000043          0.0     0.000000     0.000000     0.000066
# V90           0.000000          0.0     0.000051     0.000000     0.000089
# V91           0.000000          0.0     0.000048     0.000000     0.000085
# V95           0.000048          0.0     0.000000     0.000000     0.000070
#
#            2117,879078  2129,309534  2143,905333  2173,98153  2188,116404  \
# ID Strain
# V13           0.000000     0.000052     0.000047    0.000068     0.000050
# V142          0.000000     0.000047     0.000000    0.000091     0.000000
# V151          0.000000     0.000000     0.000047    0.000054     0.000054
# V160          0.000000     0.000051     0.000000    0.000067     0.000000
# V161          0.000000     0.000000     0.000000    0.000000     0.000000
# ...                ...          ...          ...         ...          ...
# V800          0.000000     0.000000     0.000000    0.000117     0.000000
# V82           0.000000     0.000000     0.000000    0.000053     0.000050
# V90           0.000000     0.000000     0.000000    0.000000     0.000000
# V91           0.000046     0.000000     0.000000    0.000054     0.000000
# V95           0.000000     0.000048     0.000042    0.000064     0.000000
#
#            ...  13617,65054  14104,26499  14945,23828  15048,68998  \
# ID Strain  ...
# V13        ...          0.0     0.000000     0.000066     0.000142
# V142       ...          0.0     0.000000     0.000085     0.000194
# V151       ...          0.0     0.000000     0.000092     0.000070
# V160       ...          0.0     0.000000     0.000098     0.000136
# V161       ...          0.0     0.000000     0.000089     0.000203
# ...        ...          ...          ...          ...          ...
# V800       ...          0.0     0.000036     0.000073     0.000060
# V82        ...          0.0     0.000000     0.000090     0.000144
# V90        ...          0.0     0.000000     0.000104     0.000137
# V91        ...          0.0     0.000000     0.000093     0.000214
# V95        ...          0.0     0.000000     0.000066     0.000045
#
#            15154,39575  15353,52046  15399,07159  15495,16655  16076,29338  \
# ID Strain
# V13                0.0          0.0     0.000000          0.0          0.0
# V142               0.0          0.0     0.000000          0.0          0.0
# V151               0.0          0.0     0.000000          0.0          0.0
# V160               0.0          0.0     0.000000          0.0          0.0
# V161               0.0          0.0     0.000000          0.0          0.0
# ...                ...          ...          ...          ...          ...
# V800               0.0          0.0     0.000000          0.0          0.0
# V82                0.0          0.0     0.000000          0.0          0.0
# V90                0.0          0.0     0.000051          0.0          0.0
# V91                0.0          0.0     0.000000          0.0          0.0
# V95                0.0          0.0     0.000000          0.0          0.0
#
#            16202,09535
# ID Strain
# V13                0.0
# V142               0.0
# V151               0.0
# V160               0.0
# V161               0.0
# ...                ...
# V800               0.0
# V82                0.0
# V90                0.0
# V91                0.0
# V95                0.0
#
# [154 rows x 304 columns]

# %%
map_target = {
    "Streptococcus canis" : 0,
    "Streptococcus dysgalactiae subsp. equisimilis" : 1,
    "Streptococcus dysgalactiae subsp. dysgalactiae" : 2  
}
maldi['target'] = principali["Putative Subspecies"].map(map_target)
#sns.pairplot(data=maldi, hue='target')
maldi[['target']].sample(10)
# Out:
#            target
# ID Strain
# V658            1
# V52             1
# V725            2
# V217            2
# V755            2
# V637            1
# V543            0
# V689            2
# V756            2
# V30             0

# %% [markdown]
# #### Ricerca correllazioni più alte con variabile target

# %%
corr = maldi.corr()
corr
# Out:
#              2057,143278  2064,798679  2071,138797  2085,647901  2103,986922  \
# 2057,143278     1.000000    -0.068457    -0.066517     0.493853     0.380472
# 2064,798679    -0.068457     1.000000    -0.006892     0.068057    -0.042973
# 2071,138797    -0.066517    -0.006892     1.000000    -0.065008     0.051752
# 2085,647901     0.493853     0.068057    -0.065008     1.000000     0.349521
# 2103,986922     0.380472    -0.042973     0.051752     0.349521     1.000000
# ...                  ...          ...          ...          ...          ...
# 15399,07159    -0.236770    -0.041066     0.264887    -0.168047    -0.111735
# 15495,16655     0.326854    -0.029159    -0.028286     0.023956     0.070743
# 16076,29338    -0.045185    -0.040067    -0.040026    -0.256025    -0.304763
# 16202,09535    -0.087578    -0.044287    -0.044241    -0.289394    -0.343140
# target         -0.077452    -0.001285    -0.099858     0.219587    -0.076477
#
#              2117,879078  2129,309534  2143,905333  2173,98153  2188,116404  \
# 2057,143278    -0.031394     0.185633     0.240985    0.473723     0.384678
# 2064,798679    -0.041741    -0.034696    -0.037146    0.057989    -0.047709
# 2071,138797    -0.041721    -0.033553    -0.036940   -0.008164    -0.046862
# 2085,647901     0.151131     0.036334     0.153132    0.401137     0.149272
# 2103,986922     0.068998     0.238401     0.147754    0.650993     0.208672
# ...                  ...          ...          ...         ...          ...
# 15399,07159     0.010620    -0.166991    -0.145347   -0.184978    -0.184012
# 15495,16655    -0.182219    -0.150355    -0.134466    0.029475     0.036742
# 16076,29338    -0.251805    -0.207773    -0.183429   -0.139203    -0.128798
# 16202,09535    -0.180800    -0.228891    -0.214990   -0.204771    -0.187413
# target          0.443819    -0.204778     0.046775    0.120701    -0.005993
#
#              ...  14104,26499  14945,23828  15048,68998  15154,39575  \
# 2057,143278  ...    -0.053156    -0.246925     0.113149     0.119611
# 2064,798679  ...    -0.044438     0.030154     0.010930     0.104194
# 2071,138797  ...     0.202014     0.177975     0.047723    -0.034155
# 2085,647901  ...     0.041255     0.056237    -0.227843    -0.040405
# 2103,986922  ...     0.009707     0.054503    -0.095421    -0.087589
# ...          ...          ...          ...          ...          ...
# 15399,07159  ...     0.532930     0.410916    -0.134925    -0.082834
# 15495,16655  ...    -0.192708    -0.551438     0.661583     0.453883
# 16076,29338  ...    -0.197435    -0.528830     0.806979     0.323733
# 16202,09535  ...    -0.021207    -0.384607     0.652187     0.214881
# target       ...     0.266196     0.221659    -0.587151    -0.268616
#
#              15353,52046  15399,07159  15495,16655  16076,29338  16202,09535  \
# 2057,143278     0.219807    -0.236770     0.326854    -0.045185    -0.087578
# 2064,798679    -0.026248    -0.041066    -0.029159    -0.040067    -0.044287
# 2071,138797    -0.026192     0.264887    -0.028286    -0.040026    -0.044241
# 2085,647901    -0.016386    -0.168047     0.023956    -0.256025    -0.289394
# 2103,986922     0.036960    -0.111735     0.070743    -0.304763    -0.343140
# ...                  ...          ...          ...          ...          ...
# 15399,07159     0.009880     1.000000    -0.182203    -0.155846    -0.000985
# 15495,16655     0.449534    -0.182203     1.000000     0.334343     0.225451
# 16076,29338     0.174298    -0.155846     0.334343     1.000000     0.863215
# 16202,09535     0.083882    -0.000985     0.225451     0.863215     1.000000
# target         -0.210773     0.233494    -0.365778    -0.373514    -0.224832
#
#                target
# 2057,143278 -0.077452
# 2064,798679 -0.001285
# 2071,138797 -0.099858
# 2085,647901  0.219587
# 2103,986922 -0.076477
# ...               ...
# 15399,07159  0.233494
# 15495,16655 -0.365778
# 16076,29338 -0.373514
# 16202,09535 -0.224832
# target       1.000000
#
# [305 rows x 305 columns]

# %%
corr = corr.sort_values('target')
top_corr_inv = corr[0:5]
top_corr = corr[-6:-1]
print(top_corr[['target']])
print(top_corr_inv[['target']])
# Out:
#                target
# 6731,019005  0.832741
# 6312,28957   0.834384
# 9829,326089  0.841308
# 6891,554249  0.844212
# 3364,797303  0.854254
#                target
# 6327,306693 -0.875539
# 6710,334937 -0.745410
# 5522,688276 -0.710834
# 3762,662684 -0.703397
# 3354,28405  -0.695326

# %% [raw]
# plt.figure(figsize=(15,15))
# sns.heatmap(data=corr[['target']], cmap="Blues", annot=True, linewidths=0.5, linecolor="Black")
# plt.tight_layout()
# plt.show()

# %% [markdown]
# #### Pairplot 10 best correlation score

# %%
map_target_to_name = {
    0 : "Strept. canis",
    1 : "Strept. dysg. equisimilis",
    2 : "Strept. dysg. dysgalactiae"  
}
pairplot = maldi[top_corr.index.to_series()]
pairplot['target'] = maldi['target'].map(map_target_to_name)

sns.pairplot(data=pairplot, hue="target", palette=sns.color_palette('Set1'))
plt.show()

# %%
pairplot = maldi[top_corr_inv.index.to_series()]
pairplot['target'] = maldi['target'].map(map_target_to_name)
sns.pairplot(data=pairplot, hue="target", palette=sns.color_palette('Set1'))
plt.show()

# %%
s1 = top_corr_inv.index
s2 = top_corr.index
boxplot_col = np.concatenate([s1, s2])
boxplot = maldi[boxplot_col]
boxplot['target'] = maldi['target'].map(map_target_to_name)
fig = plt.figure(figsize=(10, 12))
axes = fig.subplots(nrows=5, ncols=2)
for ax, column in zip(axes.flat, boxplot):
    sns.boxplot(y="target", x=column, data=boxplot, ax=ax)
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(18, 4))
ax = fig.subplots()
parallel_coordinates(boxplot, class_column="target", ax=ax)
plt.tight_layout()
fig.show()

# %% [markdown]
# ## Antibiotici

# %%
boxplot = antibiotici[0:10]
boxplot
# Out:
#           Eritromicina Ceftiofur Tetraciclina Gentamicina Penicillina  \
# ID Strain
# V13                 NS         S           NS          NS           S
# V142                NS         S            S           S           S
# V151                 S         S            S          NS           S
# V160                 S         S           NS          NS           S
# V161                 S         S            S          NS           S
# V175                 S         S           NS           S           S
# V186                 S         S            S           S           S
# V188                 S         S            S           S           S
# V190                NS         S           NS          NS           S
# V195                 S         S           NS          NS           S
#
#           Ampicillina Sulfametossazolo_trimethoprim Clindamicina Enrofloxacin
# ID Strain
# V13                 S                             S            S           NS
# V142                S                             S            S           NS
# V151                S                             S            S           NS
# V160                S                             S            S           NS
# V161                S                             S            S           NS
# V175                S                             S            S            S
# V186                S                             S            S           NS
# V188                S                             S            S            S
# V190                S                             S            S            S
# V195                S                             S            S           NS

# %%
fig = plt.figure(figsize=(10, 12))
axes = fig.subplots(nrows=5, ncols=2)
for ax, column in zip(axes.flat, boxplot):
    sns.countplot(y=column, data=antibiotici, ax=ax)
plt.tight_layout()
plt.show()

# %% [markdown]
# Da questo grafico possiamo notare come per gli antibiotici:
# - Ceftiofur
# - Penicillina
# - Ampicillina
# - Quasi totalmente anche Sulfametossazolo_trimethoprim
#
# Si ha il 100% delle volte o quasi, sensibilità all'antibiotico, è inutile quindi cercare di creare un modello di previsione su di loro, il dataset è troppo sbilanciato per poter dar risultati veritieri
