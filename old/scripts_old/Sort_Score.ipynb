# %%
import pandas as pd
import numpy as np
from sklearn.metrics import balanced_accuracy_score, accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, make_scorer
from sklearn.model_selection import train_test_split, cross_val_score, cross_validate, StratifiedKFold, RandomizedSearchCV
from sklearn.linear_model import LogisticRegression, RidgeClassifier, LassoCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier, NearestCentroid
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.base import clone
from sklearn.naive_bayes import BernoulliNB, GaussianNB
import dataframe_image as dfi

import warnings
    
# warnings -> to silence warnings

warnings.filterwarnings("ignore")
np.set_printoptions(precision=5, suppress=True)


RANDOM_STATE = 1
N_JOBS = -1

class_names = ["Canis", "Dysg. Equisimilis", "Dysg. Dysgalactiae"]

map_target = {
    "Streptococcus canis": 0,
    "Streptococcus dysgalactiae subsp. equisimilis": 1,
    "Streptococcus dysgalactiae subsp. dysgalactiae": 2
}

map_target_inv = {
    0: "Strept. canis",
    1: "Strept. dysg. equisimilis",
    2: "Strept. dysg. dysgalactiae"
}
map_target_antibiotici = {
    "S" : 1,
    "NS" : 0
}

start = 9
n_antibiotici = 9
n_geni = 27
n_virulenza = 18
n_picchi = ['46','306']

# %%
for n in n_picchi:
    print('DATAFRAME CON '+n+' PICCHI')
    df = pd.read_csv("../data/Dati_Matemaldomics_"+n+"picchi.csv",
                    delimiter=';', index_col='ID Strain')
    n = int(n)
    modelli = {}
    df.rename(columns = {"Putative Subspecies":'subspecies'}, inplace = True)
    subspecies = df[['subspecies']]

    st = df[[df.columns[4]]]
    antibiotici = df[df.columns[start+n:start+n+n_antibiotici]]
    geni_antibiotici = df[df.columns[start+n+n_antibiotici:start+n+n_antibiotici+n_geni]]
    virulenza = df[df.columns[start+n+n_antibiotici+n_geni:start+n+n_antibiotici+n_geni+n_virulenza]]
    
    targets = {'antibiotici' : antibiotici,
                'geni_antibiotici' : geni_antibiotici,
                'virulenza' : virulenza}
    
    for str_target,target in targets.items():
        columns = target.columns
        for column in columns:
            if str_target == 'antibiotici':
                target[column] = df[column].map(map_target_antibiotici)
            rapporto = (target[column] == 0).sum() / target.shape[0]
            #if (antibiotici[column] == 0).all() or (antibiotici[column] == 1).all():
            print(column+" : "+str(rapporto))
            if rapporto < 0.15 or rapporto > 0.85:
                target.drop([column], axis=1, inplace=True)
        
        display(target)
        
    targets['subspecies'] = subspecies
    targets['st'] = st
# Out:
# DATAFRAME CON 46 PICCHI
# Eritromicina : 0.461038961038961
# Ceftiofur : 0.0
# Tetraciclina : 0.5194805194805194
# Gentamicina : 0.6233766233766234
# Penicillina : 0.0
# Ampicillina : 0.0
# Sulfametossazolo_trimethoprim : 0.01948051948051948
# Clindamicina : 0.2662337662337662
# Enrofloxacin : 0.6688311688311688
#            Eritromicina  Tetraciclina  Gentamicina  Clindamicina  Enrofloxacin
# ID Strain
# V13                   0             0            0             1             0
# V142                  0             1            1             1             0
# V151                  1             1            0             1             0
# V160                  1             0            0             1             0
# V161                  1             1            0             1             0
# ...                 ...           ...          ...           ...           ...
# V800                  1             0            1             1             0
# V82                   1             1            0             1             1
# V90                   1             0            0             1             0
# V91                   1             1            0             1             0
# V95                   0             0            0             0             1
#
# [154 rows x 5 columns]
# aad(6) : 0.935064935064935
# ANT(6)-Ia : 0.8246753246753247
# APH(2'')-IIIa : 1.0
# APH(3')-IIIa : 0.9025974025974026
# catS : 0.9675324675324676
# dfrF : 0.9805194805194806
# E. faecalis chloramphenicol acetyltransferase : 0.9935064935064936
# Erm(47) : 0.987012987012987
# ErmB : 0.8181818181818182
# fexA : 0.9935064935064936
# L._reuteri cat-TC : 1.0
# lmrP : 0.006493506493506494
# lnuC : 0.987012987012987
# lnuD : 0.9935064935064936
# lsaC : 0.961038961038961
# lsaE : 0.7857142857142857
# mefE : 0.8506493506493507
# optrA : 0.9935064935064936
# poxtA : 0.9935064935064936
# SAT-4 : 0.922077922077922
# tet(40) : 0.987012987012987
# tet(L) : 0.9935064935064936
# tetM : 0.8181818181818182
# tetO : 0.7402597402597403
# tetS : 0.9805194805194806
# tetT : 0.974025974025974
# vatE : 0.9935064935064936
#            ANT(6)-Ia  ErmB  lsaE  tetM  tetO
# ID Strain
# V13                0     0     0     0     0
# V142               0     0     0     0     0
# V151               0     0     0     0     0
# V160               0     0     0     0     0
# V161               0     0     0     0     0
# ...              ...   ...   ...   ...   ...
# V800               0     0     0     1     0
# V82                0     0     0     0     0
# V90                0     0     0     0     0
# V91                0     0     0     0     0
# V95                1     1     1     0     1
#
# [154 rows x 5 columns]
# fbp54 : 0.0
# gbs0630 : 0.9935064935064936
# gbs0631 : 0.9935064935064936
# gbs0632 : 0.9935064935064936
# hasC : 0.0
# lmb : 0.9935064935064936
# mf2 : 0.961038961038961
# mf3 : 0.6753246753246753
# scpA : 0.9935064935064936
# sda : 0.8766233766233766
# ska : 0.9935064935064936
# slo : 0.9935064935064936
# smeZ : 0.9935064935064936
# spec : 0.974025974025974
# speg : 0.9090909090909091
# spek : 0.961038961038961
# spel : 0.974025974025974
# spem : 0.948051948051948
#            mf3
# ID Strain
# V13          0
# V142         1
# V151         0
# V160         0
# V161         1
# ...        ...
# V800         0
# V82          1
# V90          0
# V91          1
# V95          0
#
# [154 rows x 1 columns]
# DATAFRAME CON 306 PICCHI
# Eritromicina : 0.461038961038961
# Ceftiofur : 0.0
# Tetraciclina : 0.5194805194805194
# Gentamicina : 0.6233766233766234
# Penicillina : 0.0
# Ampicillina : 0.0
# Sulfametossazolo_trimethoprim : 0.01948051948051948
# Clindamicina : 0.2662337662337662
# Enrofloxacin : 0.6688311688311688
#            Eritromicina  Tetraciclina  Gentamicina  Clindamicina  Enrofloxacin
# ID Strain
# V13                   0             0            0             1             0
# V142                  0             1            1             1             0
# V151                  1             1            0             1             0
# V160                  1             0            0             1             0
# V161                  1             1            0             1             0
# ...                 ...           ...          ...           ...           ...
# V800                  1             0            1             1             0
# V82                   1             1            0             1             1
# V90                   1             0            0             1             0
# V91                   1             1            0             1             0
# V95                   0             0            0             0             1
#
# [154 rows x 5 columns]
# aad(6) : 0.935064935064935
# ANT(6)-Ia : 0.8246753246753247
# APH(2'')-IIIa : 1.0
# APH(3')-IIIa : 0.9025974025974026
# catS : 0.9675324675324676
# dfrF : 0.9805194805194806
# E. faecalis chloramphenicol acetyltransferase : 0.9935064935064936
# Erm(47) : 0.987012987012987
# ErmB : 0.8181818181818182
# fexA : 0.9935064935064936
# L._reuteri cat-TC : 1.0
# lmrP : 0.006493506493506494
# lnuC : 0.987012987012987
# lnuD : 0.9935064935064936
# lsaC : 0.961038961038961
# lsaE : 0.7857142857142857
# mefE : 0.8506493506493507
# optrA : 0.9935064935064936
# poxtA : 0.9935064935064936
# SAT-4 : 0.922077922077922
# tet(40) : 0.987012987012987
# tet(L) : 0.9935064935064936
# tetM : 0.8181818181818182
# tetO : 0.7402597402597403
# tetS : 0.9805194805194806
# tetT : 0.974025974025974
# vatE : 0.9935064935064936
#            ANT(6)-Ia  ErmB  lsaE  tetM  tetO
# ID Strain
# V13                0     0     0     0     0
# V142               0     0     0     0     0
# V151               0     0     0     0     0
# V160               0     0     0     0     0
# V161               0     0     0     0     0
# ...              ...   ...   ...   ...   ...
# V800               0     0     0     1     0
# V82                0     0     0     0     0
# V90                0     0     0     0     0
# V91                0     0     0     0     0
# V95                1     1     1     0     1
#
# [154 rows x 5 columns]
# fbp54 : 0.0
# gbs0630 : 0.9935064935064936
# gbs0631 : 0.9935064935064936
# gbs0632 : 0.9935064935064936
# hasC : 0.0
# lmb : 0.9935064935064936
# mf2 : 0.961038961038961
# mf3 : 0.6753246753246753
# scpA : 0.9935064935064936
# sda : 0.8766233766233766
# ska : 0.9935064935064936
# slo : 0.9935064935064936
# smeZ : 0.9935064935064936
# spec : 0.974025974025974
# speg : 0.9090909090909091
# spek : 0.961038961038961
# spel : 0.974025974025974
# spem : 0.948051948051948
#            mf3
# ID Strain
# V13          0
# V142         1
# V151         0
# V160         0
# V161         1
# ...        ...
# V800         0
# V82          1
# V90          0
# V91          1
# V95          0
#
# [154 rows x 1 columns]

# %%
for name_t,target in targets.items():
    for name in target:
        print(name)
        score_target = pd.read_csv('..\Risultati\Results_Def_'+str(n)+'picchi\Results_'+name+'_'+str(n)+'.csv')
        display(score_target)
        score_sort = score_target.sort_values(by=['Accuracy CV'], ascending=False)
        display(score_sort)
        #score_sort.to_csv('Risultati\Results_Def_'+str(n)+'picchi\Results_'+column+'_'+str(n)+'.csv', index = False)
# Out:
# Eritromicina
#           Target                        Model  Accuracy CV  St. Dev. CV  \
# 0   Eritromicina           LogisticRegression     0.512000     0.009798
# 1   Eritromicina      LogisticRegression_Best     0.568000     0.062738
# 2   Eritromicina       LogisticRegression_PCA     0.512000     0.009798
# 3   Eritromicina  LogisticRegression_Best_PCA     0.559667     0.099132
# 4   Eritromicina                        Ridge     0.512000     0.009798
# 5   Eritromicina                   Ridge_Best     0.551333     0.099367
# 6   Eritromicina                    Ridge_PCA     0.512000     0.009798
# 7   Eritromicina               Ridge_Best_PCA     0.512000     0.051536
# 8   Eritromicina                 DecisionTree     0.584333     0.065993
# 9   Eritromicina            DecisionTree_Best     0.561000     0.028550
# 10  Eritromicina             DecisionTree_PCA     0.520667     0.067566
# 11  Eritromicina        DecisionTree_Best_PCA     0.569000     0.020374
# 12  Eritromicina                         K-nn     0.584667     0.058485
# 13  Eritromicina                    K-nn_Best     0.608333     0.100399
# 14  Eritromicina                     K-nn_PCA     0.601000     0.088177
# 15  Eritromicina                K-nn_Best_PCA     0.552667     0.072492
# 16  Eritromicina                 RandomForest     0.543333     0.097542
# 17  Eritromicina            RandomForest_Best     0.560667     0.098142
# 18  Eritromicina             RandomForest_PCA     0.536333     0.056710
# 19  Eritromicina        RandomForest_Best_PCA     0.561333     0.043249
# 20  Eritromicina                  BernoulliNB     0.600667     0.123848
# 21  Eritromicina             BernoulliNB_Best     0.592667     0.111378
# 22  Eritromicina              BernoulliNB_PCA     0.486667     0.077717
# 23  Eritromicina         BernoulliNB_Best_PCA     0.512000     0.009798
# 24  Eritromicina                   GaussianNB     0.519333     0.096802
# 25  Eritromicina              GaussianNB_Best     0.519333     0.096802
# 26  Eritromicina               GaussianNB_PCA     0.414667     0.039376
# 27  Eritromicina          GaussianNB_Best_PCA     0.447000     0.021145
#
#     Precision CV  Recall CV  F1-Score CV  Accuracy
# 0       0.262240   0.512000     0.346807  0.645161
# 1       0.571720   0.568000     0.563947  0.709677
# 2       0.262240   0.512000     0.346807  0.645161
# 3       0.560408   0.559667     0.558473  0.645161
# 4       0.262240   0.512000     0.346807  0.645161
# 5       0.555135   0.551333     0.531760  0.709677
# 6       0.262240   0.512000     0.346807  0.645161
# 7       0.379727   0.512000     0.413185  0.580645
# 8       0.596378   0.584333     0.574232  0.645161
# 9       0.579622   0.561000     0.534501  0.580645
# 10      0.527526   0.520667     0.511456  0.451613
# 11      0.574277   0.569000     0.562943  0.516129
# 12      0.584935   0.584667     0.580943  0.709677
# 13      0.622926   0.608333     0.593680  0.645161
# 14      0.602817   0.601000     0.598540  0.645161
# 15      0.555958   0.552667     0.551029  0.516129
# 16      0.549174   0.543333     0.538593  0.741935
# 17      0.563148   0.560667     0.556625  0.774194
# 18      0.540356   0.536333     0.520529  0.612903
# 19      0.570386   0.561333     0.547403  0.580645
# 20      0.603569   0.600667     0.585726  0.677419
# 21      0.595056   0.592667     0.577726  0.677419
# 22      0.484526   0.486667     0.464250  0.354839
# 23      0.262240   0.512000     0.346807  0.645161
# 24      0.520708   0.519333     0.517243  0.612903
# 25      0.520708   0.519333     0.517243  0.612903
# 26      0.357468   0.414667     0.363232  0.354839
# 27      0.391420   0.447000     0.381511  0.322581
#           Target                        Model  Accuracy CV  St. Dev. CV  \
# 13  Eritromicina                    K-nn_Best     0.608333     0.100399
# 14  Eritromicina                     K-nn_PCA     0.601000     0.088177
# 20  Eritromicina                  BernoulliNB     0.600667     0.123848
# 21  Eritromicina             BernoulliNB_Best     0.592667     0.111378
# 12  Eritromicina                         K-nn     0.584667     0.058485
# 8   Eritromicina                 DecisionTree     0.584333     0.065993
# 11  Eritromicina        DecisionTree_Best_PCA     0.569000     0.020374
# 1   Eritromicina      LogisticRegression_Best     0.568000     0.062738
# 19  Eritromicina        RandomForest_Best_PCA     0.561333     0.043249
# 9   Eritromicina            DecisionTree_Best     0.561000     0.028550
# 17  Eritromicina            RandomForest_Best     0.560667     0.098142
# 3   Eritromicina  LogisticRegression_Best_PCA     0.559667     0.099132
# 15  Eritromicina                K-nn_Best_PCA     0.552667     0.072492
# 5   Eritromicina                   Ridge_Best     0.551333     0.099367
# 16  Eritromicina                 RandomForest     0.543333     0.097542
# 18  Eritromicina             RandomForest_PCA     0.536333     0.056710
# 10  Eritromicina             DecisionTree_PCA     0.520667     0.067566
# 24  Eritromicina                   GaussianNB     0.519333     0.096802
# 25  Eritromicina              GaussianNB_Best     0.519333     0.096802
# 23  Eritromicina         BernoulliNB_Best_PCA     0.512000     0.009798
# 0   Eritromicina           LogisticRegression     0.512000     0.009798
# 7   Eritromicina               Ridge_Best_PCA     0.512000     0.051536
# 6   Eritromicina                    Ridge_PCA     0.512000     0.009798
# 4   Eritromicina                        Ridge     0.512000     0.009798
# 2   Eritromicina       LogisticRegression_PCA     0.512000     0.009798
# 22  Eritromicina              BernoulliNB_PCA     0.486667     0.077717
# 27  Eritromicina          GaussianNB_Best_PCA     0.447000     0.021145
# 26  Eritromicina               GaussianNB_PCA     0.414667     0.039376
#
#     Precision CV  Recall CV  F1-Score CV  Accuracy
# 13      0.622926   0.608333     0.593680  0.645161
# 14      0.602817   0.601000     0.598540  0.645161
# 20      0.603569   0.600667     0.585726  0.677419
# 21      0.595056   0.592667     0.577726  0.677419
# 12      0.584935   0.584667     0.580943  0.709677
# 8       0.596378   0.584333     0.574232  0.645161
# 11      0.574277   0.569000     0.562943  0.516129
# 1       0.571720   0.568000     0.563947  0.709677
# 19      0.570386   0.561333     0.547403  0.580645
# 9       0.579622   0.561000     0.534501  0.580645
# 17      0.563148   0.560667     0.556625  0.774194
# 3       0.560408   0.559667     0.558473  0.645161
# 15      0.555958   0.552667     0.551029  0.516129
# 5       0.555135   0.551333     0.531760  0.709677
# 16      0.549174   0.543333     0.538593  0.741935
# 18      0.540356   0.536333     0.520529  0.612903
# 10      0.527526   0.520667     0.511456  0.451613
# 24      0.520708   0.519333     0.517243  0.612903
# 25      0.520708   0.519333     0.517243  0.612903
# 23      0.262240   0.512000     0.346807  0.645161
# 0       0.262240   0.512000     0.346807  0.645161
# 7       0.379727   0.512000     0.413185  0.580645
# 6       0.262240   0.512000     0.346807  0.645161
# 4       0.262240   0.512000     0.346807  0.645161
# 2       0.262240   0.512000     0.346807  0.645161
# 22      0.484526   0.486667     0.464250  0.354839
# 27      0.391420   0.447000     0.381511  0.322581
# 26      0.357468   0.414667     0.363232  0.354839
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 10
#       8 #score_sort.to_csv('Risultati\Results_Def_'+str(n)+'picchi\Results_'+column+'_'+str(n)+'.csv', index = False)
#       9 df_styled = score_sort.style.background_gradient() #adding a gradient based on values in cell
# ---> 10 dfi.export(df_styled, '..\Risultati\Sort\Results_'+name+'_'+str(n)+'.png')
#
# File d:\PycharmProjects\Thesis-Streptococcus-Classification\venv\lib\site-packages\dataframe_image\_pandas_accessor.py:48, in export(obj, filename, fontsize, max_rows, max_cols, table_conversion, chrome_path, dpi)
#      38 def export(
#      39     obj,
#      40     filename,
#    (...)
#      46     dpi=None
#      47 ):
# ---> 48     return _export(
#      49         obj, filename, fontsize, max_rows, max_cols, table_conversion, chrome_path, dpi
#      50    )
#
# File d:\PycharmProjects\Thesis-Streptococcus-Classification\venv\lib\site-packages\dataframe_image\_pandas_accessor.py:58, in _export(obj, filename, fontsize, max_rows, max_cols, table_conversion, chrome_path, dpi)
#      55 df = obj.data if is_styler else obj
#      57 if table_conversion == "chrome":
# ---> 58     converter = Screenshot(
#      59         max_rows=max_rows,
#      60         max_cols=max_cols,
#      61         chrome_path=chrome_path,
#      62         fontsize=fontsize,
#      63         encode_base64=False,
#      64         limit_crop=False,
#      65         device_scale_factor=(1 if dpi == None else dpi/100.0)
#      66     ).run
#      67 else:
#      68     from ._matplotlib_table import TableMaker
#
# File d:\PycharmProjects\Thesis-Streptococcus-Classification\venv\lib\site-packages\dataframe_image\_screenshot.py:93, in Screenshot.__init__(self, center_df, max_rows, max_cols, chrome_path, fontsize, encode_base64, limit_crop, device_scale_factor)
#      91 self.ss_width = 1400
#      92 self.ss_height = 900
# ---> 93 self.chrome_path = get_chrome_path(chrome_path)
#      94 self.css = self.get_css(fontsize)
#      95 self.encode_base64 = encode_base64
#
# File d:\PycharmProjects\Thesis-Streptococcus-Classification\venv\lib\site-packages\dataframe_image\_screenshot.py:69, in get_chrome_path(chrome_path)
#      64 locs = [
#      65     r"SOFTWARE\Microsoft\Windows\CurrentVersion\App Paths\chrome.exe",
#      66     r"SOFTWARE\Microsoft\Windows\CurrentVersion\App Paths\brave.exe",
#      67 ]
#      68 for loc in locs:
# ---> 69     handle = winreg.OpenKey(winreg.HKEY_LOCAL_MACHINE, loc)
#      70     num_values = winreg.QueryInfoKey(handle)[1]
#      71     if num_values > 0:
#
# FileNotFoundError: [WinError 2] Impossibile trovare il file specificato
